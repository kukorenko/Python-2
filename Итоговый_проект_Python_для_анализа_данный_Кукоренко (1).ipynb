# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.figure_factory as ff
import numpy as np
import scipy. stats as stats

# %% [markdown]
# ЗАДАНИЕ 1

# %%
df = pd.read_csv('/content/HR.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# ЗАДАНИЕ 2

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ЗАДАНИЕ 3

# %%
corr = df.corr()
corr.style.background_gradient(cmap='seismic')
# Out:
# <ipython-input-112-90b00406d125>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <style type="text/css">
# #T_1bb55_row0_col0, #T_1bb55_row1_col1, #T_1bb55_row2_col2, #T_1bb55_row3_col3, #T_1bb55_row4_col4, #T_1bb55_row5_col5, #T_1bb55_row6_col6, #T_1bb55_row7_col7 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_1bb55_row0_col1 {
#   background-color: #00009b;
#   color: #f1f1f1;
# }
# #T_1bb55_row0_col2, #T_1bb55_row0_col3, #T_1bb55_row0_col4, #T_1bb55_row0_col6, #T_1bb55_row5_col1, #T_1bb55_row6_col0, #T_1bb55_row6_col5, #T_1bb55_row6_col7, #T_1bb55_row7_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# #T_1bb55_row0_col5 {
#   background-color: #0000d0;
#   color: #f1f1f1;
# }
# #T_1bb55_row0_col7 {
#   background-color: #000087;
#   color: #f1f1f1;
# }
# #T_1bb55_row1_col0, #T_1bb55_row1_col3, #T_1bb55_row2_col1 {
#   background-color: #6969ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row1_col2 {
#   background-color: #b9b9ff;
#   color: #000000;
# }
# #T_1bb55_row1_col4 {
#   background-color: #0000e4;
#   color: #f1f1f1;
# }
# #T_1bb55_row1_col5, #T_1bb55_row3_col5 {
#   background-color: #0000a6;
#   color: #f1f1f1;
# }
# #T_1bb55_row1_col6 {
#   background-color: #2121ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row1_col7 {
#   background-color: #00006e;
#   color: #f1f1f1;
# }
# #T_1bb55_row2_col0 {
#   background-color: #0000ca;
#   color: #f1f1f1;
# }
# #T_1bb55_row2_col3 {
#   background-color: #b5b5ff;
#   color: #000000;
# }
# #T_1bb55_row2_col4 {
#   background-color: #1515ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row2_col5 {
#   background-color: #0000a9;
#   color: #f1f1f1;
# }
# #T_1bb55_row2_col6 {
#   background-color: #2d2dff;
#   color: #f1f1f1;
# }
# #T_1bb55_row2_col7 {
#   background-color: #000071;
#   color: #f1f1f1;
# }
# #T_1bb55_row3_col0 {
#   background-color: #0d0dff;
#   color: #f1f1f1;
# }
# #T_1bb55_row3_col1 {
#   background-color: #6161ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row3_col2 {
#   background-color: #f5f5ff;
#   color: #000000;
# }
# #T_1bb55_row3_col4, #T_1bb55_row4_col0 {
#   background-color: #0000e1;
#   color: #f1f1f1;
# }
# #T_1bb55_row3_col6 {
#   background-color: #5151ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row3_col7 {
#   background-color: #000074;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col1 {
#   background-color: #0000ae;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col2, #T_1bb55_row7_col0 {
#   background-color: #3131ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col3, #T_1bb55_row6_col2 {
#   background-color: #0000b4;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col5 {
#   background-color: #0000ac;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col6 {
#   background-color: #8989ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row4_col7 {
#   background-color: #0000a3;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col0 {
#   background-color: #4949ff;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col2, #T_1bb55_row7_col2 {
#   background-color: #0000a0;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col3 {
#   background-color: #000052;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col4 {
#   background-color: #00008d;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col6 {
#   background-color: #0000c5;
#   color: #f1f1f1;
# }
# #T_1bb55_row5_col7 {
#   background-color: #000090;
#   color: #f1f1f1;
# }
# #T_1bb55_row6_col1 {
#   background-color: #000055;
#   color: #f1f1f1;
# }
# #T_1bb55_row6_col3 {
#   background-color: #00008a;
#   color: #f1f1f1;
# }
# #T_1bb55_row6_col4 {
#   background-color: #0000ec;
#   color: #f1f1f1;
# }
# #T_1bb55_row7_col3 {
#   background-color: #000058;
#   color: #f1f1f1;
# }
# #T_1bb55_row7_col4 {
#   background-color: #0000ba;
#   color: #f1f1f1;
# }
# #T_1bb55_row7_col5 {
#   background-color: #0000c2;
#   color: #f1f1f1;
# }
# #T_1bb55_row7_col6 {
#   background-color: #0000f4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1bb55" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bb55_level0_col0" class="col_heading level0 col0" >satisfaction_level</th>
#       <th id="T_1bb55_level0_col1" class="col_heading level0 col1" >last_evaluation</th>
#       <th id="T_1bb55_level0_col2" class="col_heading level0 col2" >number_project</th>
#       <th id="T_1bb55_level0_col3" class="col_heading level0 col3" >average_montly_hours</th>
#       <th id="T_1bb55_level0_col4" class="col_heading level0 col4" >time_spend_company</th>
#       <th id="T_1bb55_level0_col5" class="col_heading level0 col5" >Work_accident</th>
#       <th id="T_1bb55_level0_col6" class="col_heading level0 col6" >left</th>
#       <th id="T_1bb55_level0_col7" class="col_heading level0 col7" >promotion_last_5years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bb55_level0_row0" class="row_heading level0 row0" >satisfaction_level</th>
#       <td id="T_1bb55_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1bb55_row0_col1" class="data row0 col1" >0.105021</td>
#       <td id="T_1bb55_row0_col2" class="data row0 col2" >-0.142970</td>
#       <td id="T_1bb55_row0_col3" class="data row0 col3" >-0.020048</td>
#       <td id="T_1bb55_row0_col4" class="data row0 col4" >-0.100866</td>
#       <td id="T_1bb55_row0_col5" class="data row0 col5" >0.058697</td>
#       <td id="T_1bb55_row0_col6" class="data row0 col6" >-0.388375</td>
#       <td id="T_1bb55_row0_col7" class="data row0 col7" >0.025605</td>
#     </tr>
#     <tr>
#       <th id="T_1bb55_level0_row1" class="row_heading level0 row1" >last_evaluation</th>
#       <td id="T_1bb55_row1_col0" class="data row1 col0" >0.105021</td>
#       <td id="T_1bb55_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1bb55_row1_col2" class="data row1 col2" >0.349333</td>
#       <td id="T_1bb55_row1_col3" class="data row1 col3" >0.339742</td>
#       <td id="T_1bb55_row1_col4" class="data row1 col4" >0.131591</td>
#       <td id="T_1bb55_row1_col5" class="data row1 col5" >-0.007104</td>
#       <td id="T_1bb55_row1_col6" class="data row1 col6" >0.006567</td>
#       <td id="T_1bb55_row1_col7" class="data row1 col7" >-0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_1bb55_level0_row2" class="row_heading level0 row2" >number_project</th>
#       <td id="T_1bb55_row2_col0" class="data row2 col0" >-0.142970</td>
#       <td id="T_1bb55_row2_col1" class="data row2 col1" >0.349333</td>
#       <td id="T_1bb55_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1bb55_row2_col3" class="data row2 col3" >0.417211</td>
#       <td id="T_1bb55_row2_col4" class="data row2 col4" >0.196786</td>
#       <td id="T_1bb55_row2_col5" class="data row2 col5" >-0.004741</td>
#       <td id="T_1bb55_row2_col6" class="data row2 col6" >0.023787</td>
#       <td id="T_1bb55_row2_col7" class="data row2 col7" >-0.006064</td>
#     </tr>
#     <tr>
#       <th id="T_1bb55_level0_row3" class="row_heading level0 row3" >average_montly_hours</th>
#       <td id="T_1bb55_row3_col0" class="data row3 col0" >-0.020048</td>
#       <td id="T_1bb55_row3_col1" class="data row3 col1" >0.339742</td>
#       <td id="T_1bb55_row3_col2" class="data row3 col2" >0.417211</td>
#       <td id="T_1bb55_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1bb55_row3_col4" class="data row3 col4" >0.127755</td>
#       <td id="T_1bb55_row3_col5" class="data row3 col5" >-0.010143</td>
#       <td id="T_1bb55_row3_col6" class="data row3 col6" >0.071287</td>
#       <td id="T_1bb55_row3_col7" class="data row3 col7" >-0.003544</td>
#     </tr>
#     <tr>
#       <th id="T_1bb55_level0_row4" class="row_heading level0 row4" >time_spend_company</th>
#       <td id="T_1bb55_row4_col0" class="data row4 col0" >-0.100866</td>
#       <td id="T_1bb55_row4_col1" class="data row4 col1" >0.131591</td>
#       <td id="T_1bb55_row4_col2" class="data row4 col2" >0.196786</td>
#       <td id="T_1bb55_row4_col3" class="data row4 col3" >0.127755</td>
#       <td id="T_1bb55_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_1bb55_row4_col5" class="data row4 col5" >0.002120</td>
#       <td id="T_1bb55_row4_col6" class="data row4 col6" >0.144822</td>
#       <td id="T_1bb55_row4_col7" class="data row4 col7" >0.067433</td>
#     </tr>
#     <tr>
#       <th id="T_1bb55_level0_row5" class="row_heading level0 row5" >Work_accident</th>
#       <td id="T_1bb55_row5_col0" class="data row5 col0" >0.058697</td>
#       <td id="T_1bb55_row5_col1" class="data row5 col1" >-0.007104</td>
#       <td id="T_1bb55_row5_col2" class="data row5 col2" >-0.004741</td>
#       <td id="T_1bb55_row

# %% [markdown]
# Две самые скоррелированные переменные - average_montly_hours и number_project; две наименее скоррелированные переменные - Work_accident и time_spend_company

# %% [markdown]
# ЗАДАНИЕ 4

# %%
agg_func_count = {'department': ['count']}
df.groupby(['department']).agg(agg_func_count)
# Out:
#             department
#                  count
# department
# IT                1227
# RandD              787
# accounting         767
# hr                 739
# management         630
# marketing          858
# product_mng        902
# sales             4140
# support           2229
# technical         2720

# %% [markdown]
# ЗАДАНИЕ 5

# %%
agg_func_salary_count = {'salary': ['count']}
df.groupby(['salary']).agg(agg_func_salary_count)
# Out:
#        salary
#         count
# salary
# high     1237
# low      7316
# medium   6446

# %% [markdown]
# ЗАДАНИЕ 6

# %%
df.pivot_table(index='department', columns='salary', values='satisfaction_level', aggfunc='count').head(10)
# Out:
# salary       high   low  medium
# department
# IT             83   609     535
# RandD          51   364     372
# accounting     74   358     335
# hr             45   335     359
# management    225   180     225
# marketing      80   402     376
# product_mng    68   451     383
# sales         269  2099    1772
# support       141  1146     942
# technical     201  1372    1147

# %% [markdown]
# ЗАДАНИЕ 7

# %% [markdown]
# H0: average_montly_hours	при salary = high > average_montly_hours	при salary = low
#
# H1: average_montly_hours	при salary = high <= average_montly_hours	при salary = low

# %%
salary_levels = df.groupby('salary')['average_montly_hours'].apply(list)
salary_levels.head()
# Out:
# salary
# high      [149, 289, 156, 129, 149, 278, 156, 143, 255, ...
# low       [157, 223, 159, 153, 247, 259, 224, 142, 135, ...
# medium    [262, 272, 226, 308, 244, 132, 286, 161, 153, ...
# Name: average_montly_hours, dtype: object

# %%
high_salary = salary_levels['high']
low_salary = salary_levels['low']

# %%
len(high_salary)
# Out:
# 1237

# %%
len(low_salary)
# Out:
# 7316

# %%
hypothesis_result = any(a > b for a, b in zip(high_salary, low_salary))
print("Результат гипотезы:", hypothesis_result)
# Out:
# Результат гипотезы: True

# %% [markdown]
# ЗАДАНИЕ 8

# %%
df_calc = df[['left','promotion_last_5years', 'satisfaction_level', 'number_project']]

# %%
df_calc_fired = df_calc[df_calc['left']==1]
df_calc_nonfired = df_calc[df_calc['left']==0]

# %%
def share_count(data_frame):
  return data_frame[data_frame['promotion_last_5years'] == 1].count()/data_frame['promotion_last_5years'].count()

# %%
share_count(df_calc_fired)
# Out:
# left                     0.005321
# promotion_last_5years    0.005321
# satisfaction_level       0.005321
# number_project           0.005321
# dtype: float64

# %%
share_count(df_calc_nonfired)
# Out:
# left                     0.026251
# promotion_last_5years    0.026251
# satisfaction_level       0.026251
# number_project           0.026251
# dtype: float64

# %%
df_calc_fired.agg({'satisfaction_level': ['mean'],
        'number_project' : ['mean']})
# Out:
#       satisfaction_level  number_project
# mean            0.440098        3.855503

# %%
df_calc_nonfired.agg({'satisfaction_level': ['mean'],
        'number_project' : ['mean']})
# Out:
#       satisfaction_level  number_project
# mean             0.66681        3.786664

# %% [markdown]
# ЗАДАНИЕ 9

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X = df[['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years']]
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-6.63083378e-01,  8.25430084e-02, -3.41244819e-02,  6.46864362e-04,
#         3.24415219e-02, -1.57648750e-01, -1.62859898e-01])

# %%
lr.predict(X_test)
# Out:
# array([ 0.45411639, -0.04497279, -0.0455815 , ...,  0.45811932,
#         0.10373558,  0.03427537])

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 0.1479642850630311
